# %% [markdown]
# # 165: Population densité

# %%
import os
import sys

current_dir = os.getcwd()
parent_dir = os.path.dirname(os.getcwd())
while not current_dir.endswith("13_odis"):
    print("changing to parent dir")
    os.chdir(parent_dir)
    current_dir = parent_dir
    parent_dir = os.path.dirname(current_dir)

print(os.getcwd())
sys.path.append(current_dir)

import pandas as pd
import datetime
import json

from common.config import load_config
from common.data_source_model import DataSourceModel
from common.utils.file_handler import FileHandler
from common.utils.interfaces.data_handler import OperationType
# Out:
# /home/jtroadec/projects/playground/13_odis

# %% [markdown]
# Columns:
# - GEO: code geographique
# - TIME_PERIOD: période temporelle ou point dans le temps auquel l'observation se réfère effectivement
# - FREQ: intervalle de temps séparant deux observations
# - OCS: catégorie de logement (résidence principale, logements vacants, logements neufs mais non occupés, logements occasionnels, résidences secondaires)
#     - _T : Total
#     - DW_MAIN : Résidences principales
#     - DW_SEC_DW_OCC : Résidences secondaires et logements occasionnels
#     - DW_VAC : Logements vacants
# - RP_MEASURE: Mesure de recensement
#     - BRTH : Nombre de naissances cumulées entre deux recensements
#     - DEATH : Nombre de décès cumulés entre deux recensements
#     - DWELLINGS : Logements
#     - DWELLINGS_POPSIZE : Population des ménages
#     - POP : Population
#     - SUP : Superficie

# %%
model_name = "population.population_superficie"
filepath = 'data/imports/population/population_superficie_1.json'

# Initialize common variables
dataframes = {}
artifacts = []

config = load_config("datasources.yaml", response_model=DataSourceModel)
model = config.get_model( model_name = model_name )
start_time = datetime.datetime.now()

# Instantiate File Handler for file loads and dumps
handler = FileHandler()

# %%
model
# Out:
# DomainModel(type='MelodiExtractor', description='recuperation de la population et de la superficie pour calcul de densite', format='json', name='population.population_superficie', API='INSEE.Melodi', endpoint='/data/DS_RP_SERIE_HISTORIQUE', headers=HeaderModel(accept='application/json'), extract_params={'maxResult': 10000, 'startPeriod': '2009-01-01', 'endPeriod': '2025-10-01', 'GEO': ['COM', 'DEP', 'REG'], 'RP_MEASURE': ['POP', 'SUP'], 'OCS': '_T'}, response_map={'data': 'observations', 'next': 'paging.next', 'is_last': 'paging.isLast'}, preprocessor=None, load_params=DataLoadParameters(separator=';', header=0, skipfooter=0), notebook_path=None, table_name='population_population_superficie', domain_name='population')

# %%
config
# Out:
# DataSourceModel(APIs={'INSEE.Metadonnees': APIModel(name='Metadonnees INSEE', base_url=HttpUrl('https://api.insee.fr/metadonnees/V1'), apidoc=HttpUrl('https://api.insee.fr/catalogue/site/themes/wso2/subthemes/insee/pages/item-info.jag?name=M%C3%A9tadonn%C3%A9es&version=V1&provider=insee'), description='INSEE - API des métadonnées', default_headers=HeaderModel(accept='application/json'), throttle=30), 'INSEE.Melodi': APIModel(name='MELODI', base_url=HttpUrl('https://api.insee.fr/melodi'), apidoc=HttpUrl('https://portail-api.insee.fr/catalog/api/a890b735-159c-4c91-90b7-35159c7c9126/doc?page=ee625968-272a-4637-a259-68272aa63766'), description='INSEE - API de données locales', default_headers=HeaderModel(accept='application/json'), throttle=30), 'INSEE.statistiques': APIModel(name='Statistiques INSEE', base_url=HttpUrl('https://www.insee.fr/fr/statistiques'), apidoc=None, description='URL de base de la section "Statistiques et Rapports" du site de l\'INSEE.\nOn peut y trouver des dataset élaborés et publiés par l\'INSEE,\nqui ne sont pas forcément disponibles via les API.', default_headers=None, throttle=60), 'Data.Gouv.Education': APIModel(name='Data.Gouv.Education', base_url=HttpUrl('https://data.education.gouv.fr/api/explore/v2.1/catalog/datasets'), apidoc=HttpUrl('https://data.education.gouv.fr/api/explore/v2.1/console'), description='Data.Gouv.Education - API de données', default_headers=HeaderModel(accept='application/json'), throttle=60), 'data.gouv.fr': APIModel(name='data.gouv.fr - Site web', base_url=HttpUrl('https://www.data.gouv.fr/fr'), apidoc=HttpUrl('https://www.data.gouv.fr/fr'), description="Site de statistiques open data de l'Etat", default_headers=None, throttle=60), 'devdurable.gouv.fr': APIModel(name='Site du Ministère du Développement Durable', base_url=HttpUrl('https://www.statistiques.developpement-durable.gouv.fr/'), apidoc=HttpUrl('https://www.statistiques.developpement-durable.gouv.fr/'), description='Site de statistiqeus du Ministère du Développement Durable pour téléchargement direct de fichiers', default_headers=None, throttle=500), 'GEO.api.gouv.fr': APIModel(name='GEO api.gouv.fr', base_url=HttpUrl('https://geo.api.gouv.fr/'), apidoc=HttpUrl('https://geo.api.gouv.fr/'), description='API gouvernemental pour interreoger les référentiels géographiques', default_headers=HeaderModel(accept='application/json'), throttle=120), 'DiDo': APIModel(name='DiDo Logement', base_url=HttpUrl('https://data.statistiques.developpement-durable.gouv.fr/dido/api/v1'), apidoc=HttpUrl('https://data.statistiques.developpement-durable.gouv.fr/dido/api/v1/apidoc.html#/'), description='API de données du Ministère du logement et développement durable', default_headers=HeaderModel(accept='application/json'), throttle=60), 'Opendatasoft': APIModel(name='Opendatasoft', base_url=HttpUrl('https://public.opendatasoft.com/api/explore/v2.1'), apidoc=HttpUrl('https://help.opendatasoft.com/apis/ods-explore-v2/'), description='Framework pour API REST avec un format de params spéficique pour passer des query. \nUtilisé par divers fournisseurs de data', default_headers=None, throttle=100), 'URSSAF': APIModel(name='Urssaf', base_url=HttpUrl('https://open.urssaf.fr/api/explore/v2.1'), apidoc=HttpUrl('https://help.opendatasoft.com/apis/ods-explore-v2/#tag/Dataset/operation/getRecords'), description="API des données ouverte de l'URSSAF", default_headers=HeaderModel(accept='application/json'), throttle=100), 'statistiques.francetravail.org': APIModel(name='statistiques francetravail.org', base_url=HttpUrl('https://statistiques.francetravail.org/'), apidoc=HttpUrl('https://www.francetravail.org/statistiques-analyses/'), description='Site regroupant des statistiques de france Travail', default_headers=None, throttle=60), 'datawrapper': APIModel(name='datawrapper', base_url=HttpUrl('https://datawrapper.dwcdn.net/'), apidoc=HttpUrl('https://www.datawrapper.de/'), description='Serving charts and maps for millions of readers every day.', default_header ...

# %%
input_path = "data/imports/population/population.population_superficie_1.json"

with open(input_path, "r", encoding="utf-8") as file:
        data = json.load(file)

# %%
data
# Out:
# {'identifier': 'DS_RP_SERIE_HISTORIQUE',
#  'title': {'fr': 'Série historique du recensement de la population ',
#   'en': 'Historical series of population census '},
#  'publisher': {'id': 'INSEE',
#   'label': [{'lang': 'fr',
#     'content': 'Institut national de la statistique et des etudes economiques (INSEE)'},
#    {'lang': 'en',
#     'content': 'National Institute of Statistics and Economic Studies'}]},
#  'observations': [{'dimensions': {'GEO': '2025-COM-03249',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2030.0}}},
#   {'dimensions': {'GEO': '2025-COM-03024',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2415.0}}},
#   {'dimensions': {'GEO': '2025-COM-07068',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1514.0}}},
#   {'dimensions': {'GEO': '2025-COM-01247',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2200.0}}},
#   {'dimensions': {'GEO': '2025-COM-02786',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 458.0}}},
#   {'dimensions': {'GEO': '2025-COM-03205',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2722.0}}},
#   {'dimensions': {'GEO': '2025-COM-02235',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 591.0}}},
#   {'dimensions': {'GEO': '2025-COM-02781',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 510.0}}},
#   {'dimensions': {'GEO': '2025-COM-06036',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 751.0}}},
#   {'dimensions': {'GEO': '2025-COM-07107',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2427.0}}},
#   {'dimensions': {'GEO': '2025-COM-01230',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1080.0}}},
#   {'dimensions': {'GEO': '2025-COM-01151',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2072.0}}},
#   {'dimensions': {'GEO': '2025-COM-12064',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2216.0}}},
#   {'dimensions': {'GEO': '2025-COM-10185',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1257.0}}},
#   {'dimensions': {'GEO': '2025-COM-09008',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2426.0}}},
#   {'dimensions': {'GEO': '2025-COM-12060',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1181.0}}},
#   {'dimensions': {'GEO': '2025-COM-06146',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1013.0}}},
#   {'dimensions': {'GEO': '2025-COM-02212',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 558.0}}},
#   {'dimensions': {'GEO': '2025-COM-02706',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 480.0}}},
#   {'dimensions': {'GEO': '2025-COM-02146',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 391.0}}},
#   {'dimensions': {'GEO': '2025-COM-02575',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2330.0}}},
#   {'dimensions': {'GEO': '2025-COM-02055',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 918.0}}},
#   {'dimensions': {'GEO': '2025-COM-04027',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1126.0}}},
#   {'dimensions': {'GEO': '2025-COM-05160',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1390.0}}},
#   {'dimensions': {'GEO': '2025-COM-03033',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 948.0}}},
#   {'dimensions': {'GEO': '2025-COM-02517',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 853.0}}},
#   {'dimensions': {'GEO': '2025-COM-09290',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 5918.0}}},
#   {'dimensions': {'GEO': '2025-COM-09001',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 777.0}}},
#   {'dimensions': {'GEO': '2025-COM-08370',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 915.0}}},
#   {'dimensions': {'GEO': '2025-COM-10046',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 579.0}}},
#   {'dimensions': {'GEO': '2025-COM-08107',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1731.0}}},
#   {'dimensions': {'GEO': '2025-COM-08092',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1746.0}}},
#   {'dimensions': {'GEO': '2025-COM-09147',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 358.0}}},
#   {'dimensions': {'GEO': '2025-COM-10360',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1002.0}}},
#   {'dimensions': {'GEO': '2025-COM-08344',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1240.0}}},
#   {'dimensions': {'GEO': '2025-COM-02435',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 815.0}}},
#   {'dimensions': {'GEO': '2025-COM-01397',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 189.0}}},
#   {'dimensions': {'GEO': '2025-COM-02322',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1190.0}}},
#   {'dimensions': {'GEO': '2025-COM-06017',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2144.0}}},
#   {'dimensions': {'GEO': '2025-COM-02746',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1452.0}}},
#   {'dimensions': {'GEO': '2025-COM-06014',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 635.0}}},
#   {'dimensions': {'GEO': '2025-COM-03234',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4008.0}}},
#   {'dimensions': {'GEO': '2025-COM-03312',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2981.0}}},
#   {'dimensions': {'GEO': '2025-COM-02074',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 746.0}}},
#   {'dimensions': {'GEO': '2025-COM-07069',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1549.0}}},
#   {'dimensions': {'GEO': '2025-COM-04136',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3473.0}}},
#   {'dimensions': {'GEO': '2025-COM-02798',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2144.0}}},
#   {'dimensions': {'GEO': '2025-COM-12038',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1554.0}}},
#   {'dimensions': {'GEO': '2025-COM-12197',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 5932.0}}},
#   {'dimensions': {'GEO': '2025-COM-08408',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1379.0}}},
#   {'dimensions': {'GEO': '2025-COM-08202',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 523.0}}},
#   {'dimensions': {'GEO': '2025-COM-12102',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 5077.0}}},
#   {'dimensions': {'GEO': '2025-COM-09195',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 609.0}}},
#   {'dimensions': {'GEO': '2025-COM-12118',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2801.0}}},
#   {'dimensions': {'GEO': '2025-COM-08426',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 903.0}}},
#   {'dimensions': {'GEO': '2025-COM-08374',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 364.0}}},
#   {'dimensions': {'GEO': '2025-COM-09090',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 737.0}}},
#   {'dimensions': {'GEO': '2025-COM-11411',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 704.0}}},
#   {'dimensions': {'GEO': '2025-COM-11018',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2111.0}}},
#   {'dimensions': {'GEO': '2025-COM-01197',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 243.0}}},
#   {'dimensions': {'GEO': '2025-COM-03032',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2237.0}}},
#   {'dimensions': {'GEO': '2025-COM-02454',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2561.0}}},
#   {'dimensions': {'GEO': '2025-COM-03228',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1283.0}}},
#   {'dimensions': {'GEO': '2025-COM-02031',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2370.0}}},
#   {'dimensions': {'GEO': '2025-COM-02404',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1012.0}}},
#   {'dimensions': {'GEO': '2025-COM-02546',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 381.0}}},
#   {'dimensions': {'GEO': '2025-COM-04159',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4577.0}}},
#   {'dimensions': {'GEO': '2025-COM-05098',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 7479.0}}},
#   {'dimensions': {'GEO': '2025-COM-03079',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2263.0}}},
#   {'dimensions': {'GEO': '2025-COM-04018',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3981.0}}},
#   {'dimensions': {'GEO': '2025-COM-02144',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 596.0}}},
#   {'dimensions': {'GEO': '2025-COM-01396',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 561.0}}},
#   {'dimensions': {'GEO': '2025-COM-09015',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 884.0}}},
#   {'dimensions': {'GEO': '2025-COM-10004',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2413.0}}},
#   {'dimensions': {'GEO': '2025-COM-10440',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 709.0}}},
#   {'dimensions': {'GEO': '2025-COM-09123',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 962.0}}},
#   {'dimensions': {'GEO': '2025-COM-09038',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1022.0}}},
#   {'dimensions': {'GEO': '2025-COM-11433',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2385.0}}},
#   {'dimensions': {'GEO': '2025-COM-09259',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1051.0}}},
#   {'dimensions': {'GEO': '2025-COM-09199',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3503.0}}},
#   {'dimensions': {'GEO': '2025-COM-10363',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1171.0}}},
#   {'dimensions': {'GEO': '2025-COM-10395',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2591.0}}},
#   {'dimensions': {'GEO': '2025-COM-08383',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 940.0}}},
#   {'dimensions': {'GEO': '2025-COM-11406',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1466.0}}},
#   {'dimensions': {'GEO': '2025-COM-05178',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4269.0}}},
#   {'dimensions': {'GEO': '2025-COM-04179',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3894.0}}},
#   {'dimensions': {'GEO': '2025-COM-01428',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 436.0}}},
#   {'dimensions': {'GEO': '2025-COM-02081',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 430.0}}},
#   {'dimensions': {'GEO': '2025-COM-04101',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3008.0}}},
#   {'dimensions': {'GEO': '2025-COM-02534',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 218.0}}},
#   {'dimensions': {'GEO': '2025-COM-02663',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 732.0}}},
#   {'dimensions': {'GEO': '2025-COM-02164',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 983.0}}},
#   {'dimensions': {'GEO': '2025-COM-02312',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2643.0}}},
#   {'dimensions': {'GEO': '2025-COM-05113',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1071.0}}},
#   {'dimensions': {'GEO': '2025-COM-06101',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3254.0}}},
#   {'dimensions': {'GEO': '2025-COM-02210',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 373.0}}},
#   {'dimensions': {'GEO': '2025-COM-01170',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 469.0}}},
#   {'dimensions': {'GEO': '2025-COM-01141',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 487.0}}},
#   {'dimensions': {'GEO': '2025-COM-01121',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 545.0}}},
#   {'dimensions': {'GEO': '2025-COM-01337',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1649.0}}},
#   {'dimensions': {'GEO': '2025-COM-07004',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1220.0}}},
#   {'dimensions': {'GEO': '2025-COM-02281',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1237.0}}},
#   {'dimensions': {'GEO': '2025-COM-04017',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3453.0}}},
#   {'dimensions': {'GEO': '2025-COM-06033',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1511.0}}},
#   {'dimensions': {'GEO': '2025-COM-07089',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1400.0}}},
#   {'dimensions': {'GEO': '2025-COM-02132',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 874.0}}},
#   {'dimensions': {'GEO': '2025-COM-02732',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 638.0}}},
#   {'dimensions': {'GEO': '2025-COM-02654',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 396.0}}},
#   {'dimensions': {'GEO': '2025-COM-07136',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1344.0}}},
#   {'dimensions': {'GEO': '2025-COM-04181',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2114.0}}},
#   {'dimensions': {'GEO': '2025-COM-02100',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 798.0}}},
#   {'dimensions': {'GEO': '2025-COM-09291',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1838.0}}},
#   {'dimensions': {'GEO': '2025-COM-08316',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1012.0}}},
#   {'dimensions': {'GEO': '2025-COM-08348',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 341.0}}},
#   {'dimensions': {'GEO': '2025-COM-07188',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1400.0}}},
#   {'dimensions': {'GEO': '2025-COM-08035',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 824.0}}},
#   {'dimensions': {'GEO': '2025-COM-08349',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 650.0}}},
#   {'dimensions': {'GEO': '2025-COM-10296',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1135.0}}},
#   {'dimensions': {'GEO': '2025-COM-08189',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1153.0}}},
#   {'dimensions': {'GEO': '2025-COM-10091',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1368.0}}},
#   {'dimensions': {'GEO': '2025-COM-10248',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1125.0}}},
#   {'dimensions': {'GEO': '2025-COM-10224',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2031.0}}},
#   {'dimensions': {'GEO': '2025-COM-10382',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1999.0}}},
#   {'dimensions': {'GEO': '2025-COM-07146',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 795.0}}},
#   {'dimensions': {'GEO': '2025-COM-03093',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1088.0}}},
#   {'dimensions': {'GEO': '2025-COM-02326',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 903.0}}},
#   {'dimensions': {'GEO': '2025-COM-02358',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1126.0}}},
#   {'dimensions': {'GEO': '2025-COM-02681',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 778.0}}},
#   {'dimensions': {'GEO': '2025-COM-02687',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1202.0}}},
#   {'dimensions': {'GEO': '2025-COM-02595',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 371.0}}},
#   {'dimensions': {'GEO': '2025-COM-02047',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 669.0}}},
#   {'dimensions': {'GEO': '2025-COM-07098',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1284.0}}},
#   {'dimensions': {'GEO': '2025-COM-02241',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1045.0}}},
#   {'dimensions': {'GEO': '2025-COM-02462',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 881.0}}},
#   {'dimensions': {'GEO': '2025-COM-03048',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 7055.0}}},
#   {'dimensions': {'GEO': '2025-COM-01190',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1344.0}}},
#   {'dimensions': {'GEO': '2025-COM-10215',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1516.0}}},
#   {'dimensions': {'GEO': '2025-COM-08143',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 780.0}}},
#   {'dimensions': {'GEO': '2025-COM-08246',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2043.0}}},
#   {'dimensions': {'GEO': '2025-COM-10042',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1650.0}}},
#   {'dimensions': {'GEO': '2025-COM-11254',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 5503.0}}},
#   {'dimensions': {'GEO': '2025-COM-10020',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2762.0}}},
#   {'dimensions': {'GEO': '2025-COM-10082',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1924.0}}},
#   {'dimensions': {'GEO': '2025-COM-07216',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1940.0}}},
#   {'dimensions': {'GEO': '2025-COM-08019',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 447.0}}},
#   {'dimensions': {'GEO': '2025-COM-11284',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 477.0}}},
#   {'dimensions': {'GEO': '2025-COM-09051',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1468.0}}},
#   {'dimensions': {'GEO': '2025-COM-07277',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 753.0}}},
#   {'dimensions': {'GEO': '2025-COM-07132',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 722.0}}},
#   {'dimensions': {'GEO': '2025-COM-07101',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2730.0}}},
#   {'dimensions': {'GEO': '2025-COM-02576',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 523.0}}},
#   {'dimensions': {'GEO': '2025-COM-07020',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1542.0}}},
#   {'dimensions': {'GEO': '2025-COM-02320',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 533.0}}},
#   {'dimensions': {'GEO': '2025-COM-02440',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 887.0}}},
#   {'dimensions': {'GEO': '2025-COM-07112',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1729.0}}},
#   {'dimensions': {'GEO': '2025-COM-04202',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1468.0}}},
#   {'dimensions': {'GEO': '2025-COM-01244',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1375.0}}},
#   {'dimensions': {'GEO': '2025-COM-01380',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2830.0}}},
#   {'dimensions': {'GEO': '2025-COM-02198',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 340.0}}},
#   {'dimensions': {'GEO': '2025-COM-02784',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 519.0}}},
#   {'dimensions': {'GEO': '2025-COM-08387',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1530.0}}},
#   {'dimensions': {'GEO': '2025-COM-10444',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 872.0}}},
#   {'dimensions': {'GEO': '2025-COM-11374',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 834.0}}},
#   {'dimensions': {'GEO': '2025-COM-10033',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1627.0}}},
#   {'dimensions': {'GEO': '2025-COM-10288',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1073.0}}},
#   {'dimensions': {'GEO': '2025-COM-08444',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 579.0}}},
#   {'dimensions': {'GEO': '2025-COM-12107',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2903.0}}},
#   {'dimensions': {'GEO': '2025-COM-09197',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 861.0}}},
#   {'dimensions': {'GEO': '2025-COM-08492',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 444.0}}},
#   {'dimensions': {'GEO': '2025-COM-08351',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 549.0}}},
#   {'dimensions': {'GEO': '2025-COM-11343',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1113.0}}},
#   {'dimensions': {'GEO': '2025-COM-09328',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1171.0}}},
#   {'dimensions': {'GEO': '2025-COM-02459',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 730.0}}},
#   {'dimensions': {'GEO': '2025-COM-03302',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 354.0}}},
#   {'dimensions': {'GEO': '2025-COM-05183',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4253.0}}},
#   {'dimensions': {'GEO': '2025-COM-02810',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4171.0}}},
#   {'dimensions': {'GEO': '2025-COM-02181',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 473.0}}},
#   {'dimensions': {'GEO': '2025-COM-07067',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 250.0}}},
#   {'dimensions': {'GEO': '2025-COM-05112',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2656.0}}},
#   {'dimensions': {'GEO': '2025-COM-02535',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1089.0}}},
#   {'dimensions': {'GEO': '2025-COM-02665',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1245.0}}},
#   {'dimensions': {'GEO': '2025-COM-01284',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 660.0}}},
#   {'dimensions': {'GEO': '2025-COM-03282',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3973.0}}},
#   {'dimensions': {'GEO': '2025-COM-02124',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1238.0}}},
#   {'dimensions': {'GEO': '2025-COM-01050',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 905.0}}},
#   {'dimensions': {'GEO': '2025-COM-01180',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 750.0}}},
#   {'dimensions': {'GEO': '2025-COM-01345',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 261.0}}},
#   {'dimensions': {'GEO': '2025-COM-02772',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 385.0}}},
#   {'dimensions': {'GEO': '2025-COM-02765',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 403.0}}},
#   {'dimensions': {'GEO': '2025-COM-07153',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3007.0}}},
#   {'dimensions': {'GEO': '2025-COM-07083',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 773.0}}},
#   {'dimensions': {'GEO': '2025-COM-02552',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 644.0}}},
#   {'dimensions': {'GEO': '2025-COM-01383',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2597.0}}},
#   {'dimensions': {'GEO': '2025-COM-02795',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 523.0}}},
#   {'dimensions': {'GEO': '2025-COM-02044',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 332.0}}},
#   {'dimensions': {'GEO': '2025-COM-03090',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1985.0}}},
#   {'dimensions': {'GEO': '2025-COM-01282',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 591.0}}},
#   {'dimensions': {'GEO': '2025-COM-03224',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2598.0}}},
#   {'dimensions': {'GEO': '2025-COM-09237',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 289.0}}},
#   {'dimensions': {'GEO': '2025-COM-12136',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3635.0}}},
#   {'dimensions': {'GEO': '2025-COM-10115',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1576.0}}},
#   {'dimensions': {'GEO': '2025-COM-07325',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 554.0}}},
#   {'dimensions': {'GEO': '2025-COM-08222',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2805.0}}},
#   {'dimensions': {'GEO': '2025-COM-09267',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3391.0}}},
#   {'dimensions': {'GEO': '2025-COM-08102',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 959.0}}},
#   {'dimensions': {'GEO': '2025-COM-10226',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 440.0}}},
#   {'dimensions': {'GEO': '2025-COM-11150',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 846.0}}},
#   {'dimensions': {'GEO': '2025-COM-12152',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 620.0}}},
#   {'dimensions': {'GEO': '2025-COM-11119',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 361.0}}},
#   {'dimensions': {'GEO': '2025-COM-12088',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3606.0}}},
#   {'dimensions': {'GEO': '2025-COM-01143',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3388.0}}},
#   {'dimensions': {'GEO': '2025-COM-02299',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 915.0}}},
#   {'dimensions': {'GEO': '2025-COM-02422',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1621.0}}},
#   {'dimensions': {'GEO': '2025-COM-02257',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 581.0}}},
#   {'dimensions': {'GEO': '2025-COM-05145',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3717.0}}},
#   {'dimensions': {'GEO': '2025-COM-02791',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 413.0}}},
#   {'dimensions': {'GEO': '2025-COM-07029',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1916.0}}},
#   {'dimensions': {'GEO': '2025-COM-02593',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 302.0}}},
#   {'dimensions': {'GEO': '2025-COM-06005',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1774.0}}},
#   {'dimensions': {'GEO': '2025-COM-04047',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1831.0}}},
#   {'dimensions': {'GEO': '2025-COM-02801',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1372.0}}},
#   {'dimensions': {'GEO': '2025-COM-04059',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 5368.0}}},
#   {'dimensions': {'GEO': '2025-COM-01393',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2902.0}}},
#   {'dimensions': {'GEO': '2025-COM-07340',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 776.0}}},
#   {'dimensions': {'GEO': '2025-COM-11162',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1021.0}}},
#   {'dimensions': {'GEO': '2025-COM-11048',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2296.0}}},
#   {'dimensions': {'GEO': '2025-COM-08502',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1550.0}}},
#   {'dimensions': {'GEO': '2025-COM-10394',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 834.0}}},
#   {'dimensions': {'GEO': '2025-COM-11342',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 633.0}}},
#   {'dimensions': {'GEO': '2025-COM-08067',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 742.0}}},
#   {'dimensions': {'GEO': '2025-COM-11126',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1018.0}}},
#   {'dimensions': {'GEO': '2025-COM-10112',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1616.0}}},
#   {'dimensions': {'GEO': '2025-COM-10263',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1725.0}}},
#   {'dimensions': {'GEO': '2025-COM-07179',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 764.0}}},
#   {'dimensions': {'GEO': '2025-COM-10228',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1244.0}}},
#   {'dimensions': {'GEO': '2025-COM-02779',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 889.0}}},
#   {'dimensions': {'GEO': '2025-COM-04028',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4124.0}}},
#   {'dimensions': {'GEO': '2025-COM-02391',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1561.0}}},
#   {'dimensions': {'GEO': '2025-COM-05106',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1320.0}}},
#   {'dimensions': {'GEO': '2025-COM-06156',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1798.0}}},
#   {'dimensions': {'GEO': '2025-COM-02592',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1582.0}}},
#   {'dimensions': {'GEO': '2025-COM-02809',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1279.0}}},
#   {'dimensions': {'GEO': '2025-COM-03065',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1934.0}}},
#   {'dimensions': {'GEO': '2025-COM-02628',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 988.0}}},
#   {'dimensions': {'GEO': '2025-COM-05008',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1852.0}}},
#   {'dimensions': {'GEO': '2025-COM-02671',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 836.0}}},
#   {'dimensions': {'GEO': '2025-COM-02216',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 725.0}}},
#   {'dimensions': {'GEO': '2025-COM-08188',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2102.0}}},
#   {'dimensions': {'GEO': '2025-COM-08223',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 740.0}}},
#   {'dimensions': {'GEO': '2025-COM-11422',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 304.0}}},
#   {'dimensions': {'GEO': '2025-COM-08121',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 589.0}}},
#   {'dimensions': {'GEO': '2025-COM-07281',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2405.0}}},
#   {'dimensions': {'GEO': '2025-COM-09085',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 494.0}}},
#   {'dimensions': {'GEO': '2025-COM-11093',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1025.0}}},
#   {'dimensions': {'GEO': '2025-COM-11071',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1538.0}}},
# ...
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1297.0}}},
#   {'dimensions': {'GEO': '2025-COM-09297',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 108.0}}},
#   {'dimensions': {'GEO': '2025-COM-01082',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1810.0}}},
#   {'dimensions': {'GEO': '2025-COM-07205',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2373.0}}},
#   {'dimensions': {'GEO': '2025-COM-10232',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 839.0}}},
#   {'dimensions': {'GEO': '2025-COM-08415',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1857.0}}},
#   {'dimensions': {'GEO': '2025-COM-08313',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 792.0}}},
#   {'dimensions': {'GEO': '2025-COM-11010',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 949.0}}},
#   {'dimensions': {'GEO': '2025-COM-12031',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1635.0}}},
#   {'dimensions': {'GEO': '2025-COM-12002',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1764.0}}},
#   {'dimensions': {'GEO': '2025-COM-08097',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1113.0}}},
#   {'dimensions': {'GEO': '2025-COM-08033',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 947.0}}},
#   {'dimensions': {'GEO': '2025-COM-10045',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1733.0}}},
#   {'dimensions': {'GEO': '2025-COM-11381',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1843.0}}},
#   {'dimensions': {'GEO': '2025-COM-12124',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3074.0}}},
#   {'dimensions': {'GEO': '2025-COM-01456',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 205.0}}},
#   {'dimensions': {'GEO': '2025-COM-06072',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4059.0}}},
#   {'dimensions': {'GEO': '2025-COM-03148',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 948.0}}},
#   {'dimensions': {'GEO': '2025-COM-06049',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1571.0}}},
#   {'dimensions': {'GEO': '2025-COM-03170',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2348.0}}},
#   {'dimensions': {'GEO': '2025-COM-07079',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 5072.0}}},
#   {'dimensions': {'GEO': '2025-COM-03037',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2095.0}}},
#   {'dimensions': {'GEO': '2025-COM-02137',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 740.0}}},
#   {'dimensions': {'GEO': '2025-COM-02820',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1776.0}}},
#   {'dimensions': {'GEO': '2025-COM-02808',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 395.0}}},
#   {'dimensions': {'GEO': '2025-COM-01280',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1488.0}}},
#   {'dimensions': {'GEO': '2025-COM-02701',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 263.0}}},
#   {'dimensions': {'GEO': '2025-COM-10286',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1483.0}}},
#   {'dimensions': {'GEO': '2025-COM-09142',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 689.0}}},
#   {'dimensions': {'GEO': '2025-COM-10019',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2758.0}}},
#   {'dimensions': {'GEO': '2025-COM-11225',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2763.0}}},
#   {'dimensions': {'GEO': '2025-COM-10402',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1048.0}}},
#   {'dimensions': {'GEO': '2025-COM-09026',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 398.0}}},
#   {'dimensions': {'GEO': '2025-COM-09047',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2694.0}}},
#   {'dimensions': {'GEO': '2025-COM-10161',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 754.0}}},
#   {'dimensions': {'GEO': '2025-COM-08254',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1344.0}}},
#   {'dimensions': {'GEO': '2025-COM-08190',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1841.0}}},
#   {'dimensions': {'GEO': '2025-COM-11393',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1419.0}}},
#   {'dimensions': {'GEO': '2025-COM-09235',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1443.0}}},
#   {'dimensions': {'GEO': '2025-COM-02742',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 616.0}}},
#   {'dimensions': {'GEO': '2025-COM-02025',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 631.0}}},
#   {'dimensions': {'GEO': '2025-COM-05049',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2411.0}}},
#   {'dimensions': {'GEO': '2025-COM-05047',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2647.0}}},
#   {'dimensions': {'GEO': '2025-COM-05099',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1203.0}}},
#   {'dimensions': {'GEO': '2025-COM-02410',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 953.0}}},
#   {'dimensions': {'GEO': '2025-COM-02684',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 4220.0}}},
#   {'dimensions': {'GEO': '2025-COM-06022',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1229.0}}},
#   {'dimensions': {'GEO': '2025-COM-02364',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 420.0}}},
#   {'dimensions': {'GEO': '2025-COM-02149',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 400.0}}},
#   {'dimensions': {'GEO': '2025-COM-02237',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1790.0}}},
#   {'dimensions': {'GEO': '2025-COM-03138',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3301.0}}},
#   {'dimensions': {'GEO': '2025-COM-03160',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1807.0}}},
#   {'dimensions': {'GEO': '2025-COM-03111',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1127.0}}},
#   {'dimensions': {'GEO': '2025-COM-05092',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 836.0}}},
#   {'dimensions': {'GEO': '2025-COM-03181',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2342.0}}},
#   {'dimensions': {'GEO': '2025-COM-02409',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2371.0}}},
#   {'dimensions': {'GEO': '2025-COM-02817',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 264.0}}},
#   {'dimensions': {'GEO': '2025-COM-04058',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2104.0}}},
#   {'dimensions': {'GEO': '2025-COM-04076',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 6037.0}}},
#   {'dimensions': {'GEO': '2025-COM-06107',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2378.0}}},
#   {'dimensions': {'GEO': '2025-COM-02015',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 385.0}}},
#   {'dimensions': {'GEO': '2025-COM-06027',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1795.0}}},
#   {'dimensions': {'GEO': '2025-COM-02347',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 565.0}}},
#   {'dimensions': {'GEO': '2025-COM-11320',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2238.0}}},
#   {'dimensions': {'GEO': '2025-COM-11035',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1168.0}}},
#   {'dimensions': {'GEO': '2025-COM-11363',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1589.0}}},
#   {'dimensions': {'GEO': '2025-COM-10381',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1211.0}}},
#   {'dimensions': {'GEO': '2025-COM-09218',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1839.0}}},
#   {'dimensions': {'GEO': '2025-COM-08347',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1829.0}}},
#   {'dimensions': {'GEO': '2025-COM-11207',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 446.0}}},
#   {'dimensions': {'GEO': '2025-COM-08158',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 423.0}}},
#   {'dimensions': {'GEO': '2025-COM-07263',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1558.0}}},
#   {'dimensions': {'GEO': '2025-COM-10080',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 3106.0}}},
#   {'dimensions': {'GEO': '2025-COM-11115',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2506.0}}},
#   {'dimensions': {'GEO': '2025-COM-08178',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1439.0}}},
#   {'dimensions': {'GEO': '2025-COM-01108',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1687.0}}},
#   {'dimensions': {'GEO': '2025-COM-01295',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 866.0}}},
#   {'dimensions': {'GEO': '2025-COM-02200',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 930.0}}},
#   {'dimensions': {'GEO': '2025-COM-01390',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 2144.0}}},
#   {'dimensions': {'GEO': '2025-COM-02390',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 582.0}}},
#   {'dimensions': {'GEO': '2025-COM-01242',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 317.0}}},
#   {'dimensions': {'GEO': '2025-COM-02711',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 910.0}}},
#   {'dimensions': {'GEO': '2025-COM-04164',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 756.0}}},
#   {'dimensions': {'GEO': '2025-COM-02745',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 742.0}}},
#   {'dimensions': {'GEO': '2025-COM-02470',
#     'FREQ': 'A',
#     'TIME_PERIOD': '2022',
#     'RP_MEASURE': 'SUP',
#     'OCS': '_T'},
#    'measures': {'OBS_VALUE_NIVEAU': {'value': 1696.0}}},
#   ...],
#  'paging': {'first': 'https://api.insee.fr/melodi/data/DS_RP_SERIE_HISTORIQUE?maxResult=10000&startPeriod=2009-01-01&endPeriod=2025-10-01&GEO=COM&GEO=DEP&GEO=REG&RP_MEASURE=POP&RP_MEASURE=SUP&OCS=_T&page=1'}}

# %%
len(data["observations"])
# Out:
# 10000

# %%
data["identifier"]
# Out:
# 'DS_RP_SERIE_HISTORIQUE'

# %%
data["title"]
# Out:
# {'fr': 'Série historique du recensement de la population ',
#  'en': 'Historical series of population census '}

# %%
data["publisher"]
# Out:
# {'id': 'INSEE',
#  'label': [{'lang': 'fr',
#    'content': 'Institut national de la statistique et des etudes economiques (INSEE)'},
#   {'lang': 'en',
#    'content': 'National Institute of Statistics and Economic Studies'}]}

# %%
data["paging"]
# Out:
# {'first': 'https://api.insee.fr/melodi/data/DS_RP_SERIE_HISTORIQUE?maxResult=10000&startPeriod=2009-01-01&endPeriod=2025-10-01&GEO=COM&GEO=DEP&GEO=REG&RP_MEASURE=POP&RP_MEASURE=SUP&OCS=_T&page=1'}

# %%
data["observations"][0]
# Out:
# {'dimensions': {'GEO': '2025-COM-03249',
#   'FREQ': 'A',
#   'TIME_PERIOD': '2022',
#   'RP_MEASURE': 'SUP',
#   'OCS': '_T',
#   'VALUE': {'value': 2030.0}},
#  'measures': {'OBS_VALUE_NIVEAU': {'value': 2030.0}}}

# %%
rows = []
for obj in data["observations"]:
    row, value = obj.get("dimensions"), obj.get("measures")["OBS_VALUE_NIVEAU"]["value"]
    row["VALUE"] = value
    rows.append(row)

df = pd.DataFrame(rows)
df["CODEGEO"] = df["GEO"].apply(lambda x: x.split("-")[2])
df["YEARGEO"] = df["GEO"].apply(lambda x: x.split("-")[0])
df["UNKNOWN_GEO"] = df["GEO"].apply(lambda x: x.split("-")[1])

# keep SUP for superficie
cols_to_keep = ["CODEGEO", "TIME_PERIOD", "SUP"]

df_pivot = pd.pivot_table(
    data=df, 
    values="VALUE", 
    columns=["RP_MEASURE"],
    index=["GEO", "TIME_PERIOD", "FREQ", "OCS", "CODEGEO"],
    fill_value=0
).reset_index()

df_pivot
# Out:
# RP_MEASURE             GEO TIME_PERIOD FREQ OCS CODEGEO    POP     SUP
# 0           2025-COM-01001        2011    A  _T   01001  780.0     0.0
# 1           2025-COM-01001        2016    A  _T   01001  767.0     0.0
# 2           2025-COM-01001        2022    A  _T   01001  859.0  1595.0
# 3           2025-COM-01002        2011    A  _T   01002  234.0     0.0
# 4           2025-COM-01002        2016    A  _T   01002  243.0     0.0
# ...                    ...         ...  ...  ..     ...    ...     ...
# 8894        2025-COM-55248        2022    A  _T   55248    0.0  1607.0
# 8895        2025-COM-55250        2022    A  _T   55250    0.0   646.0
# 8896        2025-COM-55253        2022    A  _T   55253    0.0   555.0
# 8897        2025-COM-55255        2022    A  _T   55255    0.0  1744.0
# 8898        2025-COM-55262        2022    A  _T   55262    0.0  1642.0
#
# [8899 rows x 7 columns]

# %%
df_pivot["CODEGEO"] = df_pivot["GEO"].apply(lambda d: d.split("-")[2])
df_pivot["LEVEL_CODEGEO"] = df_pivot["GEO"].apply(lambda d: d.split("-")[1])
df_pivot["ANNEE_CODEGEO"] = df_pivot["GEO"].apply(lambda d: d.split("-")[0])
df_pivot.head()
# Out:
# RP_MEASURE             GEO TIME_PERIOD FREQ OCS CODEGEO    POP     SUP  \
# 0           2025-COM-01001        2011    A  _T   01001  780.0     0.0
# 1           2025-COM-01001        2016    A  _T   01001  767.0     0.0
# 2           2025-COM-01001        2022    A  _T   01001  859.0  1595.0
# 3           2025-COM-01002        2011    A  _T   01002  234.0     0.0
# 4           2025-COM-01002        2016    A  _T   01002  243.0     0.0
#
# RP_MEASURE ANNEE_CODEGEO LEVEL_CODEGEO
# 0                   2025           COM
# 1                   2025           COM
# 2                   2025           COM
# 3                   2025           COM
# 4                   2025           COM

# %%
df_pivot["LEVEL_CODEGEO"].unique()
# Out:
# array(['COM'], dtype=object)

# %%
df["TIME_PERIOD"].unique()
# Out:
# array(['2022', '2016', '2011'], dtype=object)

# %%
df["FREQ"].unique()
# Out:
# array(['A'], dtype=object)

# %%
df["RP_MEASURE"].unique()
# Out:
# array(['SUP', 'POP'], dtype=object)

# %%
df["GEO"].unique()
# Out:
# array(['2025-COM-03249', '2025-COM-03024', '2025-COM-07068', ...,
#        '2025-COM-06150', '2025-COM-02346', '2025-COM-05014'],
#       shape=(6402,), dtype=object)

# %%
df["CODEGEO"].nunique()
# Out:
# 6402

# %%
df["YEARGEO"].unique()
# Out:
# array(['2025'], dtype=object)

# %%
df["UNKNOWN_GEO"].unique()
# Out:
# array(['COM'], dtype=object)
